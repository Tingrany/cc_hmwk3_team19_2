# %%
from elasticsearch import Elasticsearch, RequestsHttpConnection
from requests_aws4auth import AWS4Auth
import glob
import json

# %%
bulk_file = ''
def header(i):
    return json.dumps({ "index" : { "_index": "predictions", "_type" : "Prediction", "_id" : i + 1 } }) + "\n"
with open("FILE_4.json",'r') as load_f:
#     load_dict = load_f.readlines()
    load_dict = json.load(load_f)
print(len(load_dict))
for i in range(len(load_dict)):
    bulk_file += header(i)
    bulk_file += json.dumps(load_dict[i]) + '\n'
# Out:
# 1540

# %%
AWS_ACCESS_KEY = 'AKIAJII7NFWAMU5R5MQQ'
AWS_SECRET_KEY = 'WYyy8TMEZ94eb00qDzIEDhPWU+ppbJx9v1n6WZxt'
region = 'us-east-1' # For example, us-east-1
service = 'es'

awsauth = AWS4Auth(AWS_ACCESS_KEY, AWS_SECRET_KEY, region, service)

host = 'search-test-c4yyz42af2dgbospe67euc27um.us-east-1.es.amazonaws.com' # For example, my-test-domain.us-east-1.es.amazonaws.com

# bulk_file = ''
es = Elasticsearch(
    hosts = [{'host': host, 'port': 443}],
    http_auth = awsauth,
    use_ssl = True,
    verify_certs = True,
    connection_class = RequestsHttpConnection
)

es.bulk(bulk_file)
# Out:
# {'took': 260,
#  'errors': False,
#  'items': [{'index': {'_index': 'predictions',
#     '_type': 'Prediction',
#     '_id': '1',
#     '_version': 5,
#     'result': 'updated',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1196,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'predictions',
#     '_type': 'Prediction',
#     '_id': '2',
#     '_version': 5,
#     'result': 'updated',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1184,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'predictions',
#     '_type': 'Prediction',
#     '_id': '3',
#     '_version': 5,
#     'result': 'updated',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1328,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'predictions',
#     '_type': 'Prediction',
#     '_id': '4',
#     '_version': 5,
#     'result': 'updated',
# ...
